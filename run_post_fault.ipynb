# %% [markdown]
# Instructions for training the model for post-fault operation of the system.
# 1. Uncomment Line 90 in openDSSenv34.py; which is L_OUT='L24'.
# 2. Change the L_OUT to corresponding line failure from the candidate set to get results for those failures. Candidate_Lines=['L7','L9','L15','L16','L18','L19','L21','L22','L23','L24']
# 3. Run the corresponding code blocks below to obtain results for PPO, A2C, and TRPO.
# 4. Use CustomNN class to use Multilayer Perceptrons (MLP) as feature extractor, else use CustomCNN to use Convolution Neural Network (CNN as feature extractor).

# %% [markdown]
# Import libraries

# %%
import numpy as np
import gym
from stable_baselines3 import PPO
from stable_baselines3 import A2C
from sb3_contrib import TRPO
from openDSSenv34 import openDSSenv34
import torch as th
from stable_baselines3.common.utils import set_random_seed
from numba import jit
from state_action_reward import take_action, get_state


from stable_baselines3.common.torch_layers import (
    BaseFeaturesExtractor,
    CombinedExtractor,
    FlattenExtractor,
    MlpExtractor,
    NatureCNN,
    create_mlp,
)


import pickle
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv

from stable_baselines3.common.env_util import make_vec_env
import time
import datetime

# %% [markdown]
# Prepare the Neural network for feature extraction. (1) MLP; (2) CNN

# %%
# Customer NN used in the report
class CustomNN(BaseFeaturesExtractor): # MLP

    """
    :param observation_space: (gym.Space)
    :param features_dim: (int) Number of features extracted.
        This corresponds to the number of unit for the last layer.
    """

    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 256):
        from torch import nn
        super(CustomNN, self).__init__(observation_space, features_dim)


        n_flatten = 1521# Need to adjust this to fit in the microgrid state space size
        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())

    def forward(self, observations):
        
        if len(observations["Unserved Energy"].shape) == 1:
            data_UE = observations["Unserved Energy"][:, None]
        else:
            data_UE = observations["Unserved Energy"]
       
        ################### Now Trying with the Unserved Energy into Account ################
        statevec = np.concatenate((data_UE,
                                    observations['NodeFeat(BusVoltage)'].flatten(1,2),
                                    observations['EdgeFeat(branchflow)'][:,:],
                                    observations['Adjacency'].flatten(1,2)), axis=1)
        
        statevec = np.array(statevec)
        statevec = th.from_numpy(statevec)

        # print(statevec)
        return self.linear(statevec)
    
    
class CustomCNN(BaseFeaturesExtractor): #CNN

    """
    :param observation_space: (gym.Space)
    :param features_dim: (int) Number of features extracted.
        This corresponds to the number of unit for the last layer.
    """

    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 256):
        from torch import nn
        super(CustomNN, self).__init__(observation_space, features_dim)


        n_flatten = 1521# Need to adjust this to fit in the microgrid state space size

        # define cnn layer for feature extraction
        self.cnn_layers = nn.Sequential(
            nn.Conv1d(1, 100, kernel_size=5, stride=3, padding=1),  # 1st 1D-CNN layer
            nn.ReLU(),
            nn.Conv1d(100, 100, kernel_size=5, stride=3, padding=1),  # 2nd 1D-CNN layer
            nn.ReLU(),
            nn.Conv1d(100, 100, kernel_size=5, stride=3, padding=1),  # 3rd 1D-CNN layer
            nn.ReLU(),
            nn.Flatten(1,-1),
        )
        # calculate the output shape from cnn_layers
        with th.no_grad():
            n_flatten = self.cnn_layers(
                th.as_tensor(np.empty((1,1,n_flatten))).float()
            ).shape[1]

        # add a linear layer to get expected feature dimention
        self.linear = nn.Sequential(nn.Linear(n_flatten, features_dim), nn.ReLU())


    def forward(self, observations):
        # get selected observations as state vector
        if len(observations["Unserved Energy"].shape) == 1:
            data_UE = observations["Unserved Energy"][:, None]
        else:
            data_UE = observations["Unserved Energy"]


        ################### Now Trying with the Unserved Energy into Account ################
        statevec = np.concatenate((data_UE,
                                    observations['NodeFeat(BusVoltage)'].flatten(1,2),
                                    observations['EdgeFeat(branchflow)'][:,:],
                                    observations['Adjacency'].flatten(1,2)), axis=1)

        statevec = np.array(statevec)
        statevec = th.from_numpy(statevec)

        # Add additional dimention to match 1d-cnn layer input shape.
        statevec = statevec.unsqueeze(0)
        statevec = statevec.transpose(1,0)

    
        return self.linear(self.cnn_layers(statevec))
    
    
from torch import nn
import torch

class CustomTransformer(BaseFeaturesExtractor):
    """
    :param observation_space: (gym.Space)
    :param features_dim: (int) Number of features extracted.
        This corresponds to the number of unit for the last layer.
    """

    def __init__(self, observation_space: gym.spaces.Box, features_dim: int = 256):
        super(CustomTransformer, self).__init__(observation_space, features_dim)

        self.d_model = features_dim
        self.nhead = 4
        self.num_layers = 2

        self.transformer = nn.Transformer(d_model=self.d_model, nhead=self.nhead, num_encoder_layers=self.num_layers)

        n_flatten = 1521 # Need to adjust this to fit in the microgrid state space size
        self.linear = nn.Linear(n_flatten, self.d_model)

    def forward(self, observations):
        # get selected observations as state vector
        if len(observations["Unserved Energy"].shape) == 1:
            data_UE = observations["Unserved Energy"][:, None]
        else:
            data_UE = observations["Unserved Energy"]

        ################### Now Trying with the Unserved Energy into Account ################
        statevec = np.concatenate((data_UE,
                                    observations['NodeFeat(BusVoltage)'].flatten(1,2),
                                    observations['EdgeFeat(branchflow)'][:,:],
                                    observations['Adjacency'].flatten(1,2)), axis=1)

        statevec = np.array(statevec)
        statevec = torch.from_numpy(statevec)

        # Transform the state vector to match the transformer input
        statevec = self.linear(statevec)

        # Transformer expects input of shape (S, N, E) where S is the source sequence length,
        # N is the batch size, E is the feature number
        statevec = statevec.unsqueeze(1)

        # Pass the same input to both src and tgt
        output = self.transformer(statevec, statevec)
        return output.squeeze(1)



def make_env(rank, seed=0):
    """
    Utility function for multiprocessed env.

    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environments you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    """
    def _init():
        env = openDSSenv34()
        env.seed(seed + rank)
        return env
    set_random_seed(seed)
    return _init

# %% [markdown]
# (a) Run the following code for RL algorithm: PPO

# %%
# train the model for PPO
num_cpu = 8
env=make_vec_env(openDSSenv34,n_envs=num_cpu,seed=0)

rms_prop_eps = 1e-5

# Training the model for PPO
policy_kwargs = dict(
    features_extractor_class=CustomTransformer, # chage with CustomCNN to use CNN as feature extractor
    features_extractor_kwargs=dict(features_dim=256),
    activation_fn=th.nn.Tanh,
    net_arch=[dict(vf=[128, 128])] # 
)


model = PPO('MultiInputPolicy', env,tensorboard_log="logger_PPO_narrow/", policy_kwargs=policy_kwargs, verbose=1, n_steps=100, batch_size=100,
            gamma=1.00,
            learning_rate=0.000001,#0.00001 from 0.003 to 5e-6♠
                ent_coef=0.01# 0.05
                ).learn(total_timesteps=50000, log_interval=1, tb_log_name="R1_Microgrid_env_mlp_Normal-Transformer")

log_dir = "."
model.save(log_dir + "r1_MG_bus_mlp_with_entropy_05_multi_env_normal_PPO"+str(datetime.datetime.now().day)+"_"+str(datetime.datetime.now().hour)+"_"+str(datetime.datetime.now().minute))
# Out:
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# e:\Miniconda3\envs\dlproject\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# e:\Miniconda3\envs\dlproject\lib\site-packages\stable_baselines3\common\policies.py:484: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# e:\Miniconda3\envs\dlproject\lib\site-packages\torch\nn\modules\transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Using cpu device
# Logging to logger_PPO_narrow/R1_Microgrid_env_mlp_Normal-Transformer_2
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1         |
# |    ep_rew_mean     | -6.42e-05 |
# | time/              |           |
# |    fps             | 8         |
# |    iterations      | 1         |
# |    time_elapsed    | 91        |
# |    total_timesteps | 800       |
# ----------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.13e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 2             |
# |    time_elapsed         | 210           |
# |    total_timesteps      | 1600          |
# | train/                  |               |
# |    approx_kl            | 4.5738816e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.24         |
# |    explained_variance   | 1.13e-06      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0202       |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00019      |
# |    value_loss           | 7.12          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.39e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 3            |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 2400         |
# | train/                  |              |
# |    approx_kl            | 8.125253e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -3.13        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0495      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 0.0417       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.37e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 4            |
# |    time_elapsed         | 433          |
# |    total_timesteps      | 3200         |
# | train/                  |              |
# |    approx_kl            | 7.287778e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -9.91        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0561      |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000669    |
# |    value_loss           | 0.0239       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.57e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 5            |
# |    time_elapsed         | 556          |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 6.548867e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -7.39        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0584      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000765    |
# |    value_loss           | 0.0164       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.31e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 6            |
# |    time_elapsed         | 680          |
# |    total_timesteps      | 4800         |
# | train/                  |              |
# |    approx_kl            | 9.272896e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -2.43        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0595      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.0125       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.37e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 7            |
# |    time_elapsed         | 809          |
# |    total_timesteps      | 5600         |
# | train/                  |              |
# |    approx_kl            | 7.684447e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -1.31        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0608      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 0.0106       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -0.791       |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 8            |
# |    time_elapsed         | 932          |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 9.165525e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.24        |
# |    explained_variance   | -0.441       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0626      |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 0.00901      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.26e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 9             |
# |    time_elapsed         | 1056          |
# |    total_timesteps      | 7200          |
# | train/                  |               |
# |    approx_kl            | 5.5934863e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23         |
# |    explained_variance   | 0             |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0607       |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000554     |
# |    value_loss           | 7.83          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.52e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 10           |
# |    time_elapsed         | 1172         |
# |    total_timesteps      | 8000         |
# | train/                  |              |
# |    approx_kl            | 7.089019e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.23        |
# |    explained_variance   | -0.154       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0628      |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00058     |
# |    value_loss           | 0.00758      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.37e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 11            |
# |    time_elapsed         | 1282          |
# |    total_timesteps      | 8800          |
# | train/                  |               |
# |    approx_kl            | 6.1083585e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23         |
# |    explained_variance   | -0.348        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0639       |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000212     |
# |    value_loss           | 0.00681       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.12e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 12           |
# |    time_elapsed         | 1397         |
# |    total_timesteps      | 9600         |
# | train/                  |              |
# |    approx_kl            | 4.614495e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.23        |
# |    explained_variance   | -0.145       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0614      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | 0.000315     |
# |    value_loss           | 0.00627      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.31e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 13            |
# |    time_elapsed         | 1512          |
# |    total_timesteps      | 10400         |
# | train/                  |               |
# |    approx_kl            | 3.6726742e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.23         |
# |    explained_variance   | -0.175        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.06         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 0.000688      |
# |    value_loss           | 0.00584       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.53e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 14            |
# |    time_elapsed         | 1623          |
# |    total_timesteps      | 11200         |
# | train/                  |               |
# |    approx_kl            | 2.4987534e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.22         |
# |    explained_variance   | 0             |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.062        |
# |    n_updates            | 130           |
# |    policy_gradient_loss | 0.0012        |
# |    value_loss           | 7.82          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.4e-05     |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 15           |
# |    time_elapsed         | 1738         |
# |    total_timesteps      | 12000        |
# | train/                  |              |
# |    approx_kl            | 3.298104e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.22        |
# |    explained_variance   | -0.174       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0617      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.00142      |
# |    value_loss           | 0.0058       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.44e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 16            |
# |    time_elapsed         | 1853          |
# |    total_timesteps      | 12800         |
# | train/                  |               |
# |    approx_kl            | 3.9608552e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.22         |
# |    explained_variance   | -0.0913       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0622       |
# |    n_updates            | 150           |
# |    policy_gradient_loss | 0.00147       |
# |    value_loss           | 0.00523       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.33e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 17           |
# |    time_elapsed         | 1972         |
# |    total_timesteps      | 13600        |
# | train/                  |              |
# |    approx_kl            | 3.406279e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.21        |
# |    explained_variance   | -0.0697      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0614      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00209      |
# |    value_loss           | 0.00523      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.39e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 18            |
# |    time_elapsed         | 2091          |
# |    total_timesteps      | 14400         |
# | train/                  |               |
# |    approx_kl            | 8.3358886e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.21         |
# |    explained_variance   | -0.147        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0598       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | 0.00165       |
# |    value_loss           | 0.00508       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.3e-05      |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 19            |
# |    time_elapsed         | 2210          |
# |    total_timesteps      | 15200         |
# | train/                  |               |
# |    approx_kl            | 3.9800776e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.21         |
# |    explained_variance   | -0.187        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0604       |
# |    n_updates            | 180           |
# |    policy_gradient_loss | 0.00247       |
# |    value_loss           | 0.00521       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.21e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 20            |
# |    time_elapsed         | 2328          |
# |    total_timesteps      | 16000         |
# | train/                  |               |
# |    approx_kl            | 3.3601078e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.2          |
# |    explained_variance   | -0.24         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0607       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 0.00249       |
# |    value_loss           | 0.00491       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.15e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 21            |
# |    time_elapsed         | 2443          |
# |    total_timesteps      | 16800         |
# | train/                  |               |
# |    approx_kl            | 5.9572605e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.2          |
# |    explained_variance   | -0.214        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0604       |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 0.00293       |
# |    value_loss           | 0.00484       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.23e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 22            |
# |    time_elapsed         | 2567          |
# |    total_timesteps      | 17600         |
# | train/                  |               |
# |    approx_kl            | 6.0635135e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.19         |
# |    explained_variance   | -0.387        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0594       |
# |    n_updates            | 210           |
# |    policy_gradient_loss | 0.00286       |
# |    value_loss           | 0.00486       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.1e-05      |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 23            |
# |    time_elapsed         | 2686          |
# |    total_timesteps      | 18400         |
# | train/                  |               |
# |    approx_kl            | 3.3439843e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.19         |
# |    explained_variance   | -0.365        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0592       |
# |    n_updates            | 220           |
# |    policy_gradient_loss | 0.0037        |
# |    value_loss           | 0.0049        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.44e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 24            |
# |    time_elapsed         | 2802          |
# |    total_timesteps      | 19200         |
# | train/                  |               |
# |    approx_kl            | 3.6659316e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.18         |
# |    explained_variance   | -0.754        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0587       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | 0.00353       |
# |    value_loss           | 0.00468       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.38e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 25           |
# |    time_elapsed         | 2918         |
# |    total_timesteps      | 20000        |
# | train/                  |              |
# |    approx_kl            | 6.430983e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.18        |
# |    explained_variance   | -0.711       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0603      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.00337      |
# |    value_loss           | 0.00449      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.99e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 26            |
# |    time_elapsed         | 3035          |
# |    total_timesteps      | 20800         |
# | train/                  |               |
# |    approx_kl            | 3.7339476e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.17         |
# |    explained_variance   | -0.608        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0594       |
# |    n_updates            | 250           |
# |    policy_gradient_loss | 0.00376       |
# |    value_loss           | 0.00453       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.29e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 27            |
# |    time_elapsed         | 3160          |
# |    total_timesteps      | 21600         |
# | train/                  |               |
# |    approx_kl            | 7.2541094e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.17         |
# |    explained_variance   | -0.416        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0606       |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 0.00367       |
# |    value_loss           | 0.00431       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.19e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 28            |
# |    time_elapsed         | 3295          |
# |    total_timesteps      | 22400         |
# | train/                  |               |
# |    approx_kl            | 4.8783346e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.16         |
# |    explained_variance   | -0.564        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0577       |
# |    n_updates            | 270           |
# |    policy_gradient_loss | 0.00387       |
# |    value_loss           | 0.00447       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.36e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 29           |
# |    time_elapsed         | 3434         |
# |    total_timesteps      | 23200        |
# | train/                  |              |
# |    approx_kl            | 7.228367e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.16        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0541      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.00416      |
# |    value_loss           | 7.27         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.2e-05     |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 30           |
# |    time_elapsed         | 3555         |
# |    total_timesteps      | 24000        |
# | train/                  |              |
# |    approx_kl            | 8.647777e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.15        |
# |    explained_variance   | -0.424       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0585      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.00419      |
# |    value_loss           | 0.00464      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.06e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 31           |
# |    time_elapsed         | 3681         |
# |    total_timesteps      | 24800        |
# | train/                  |              |
# |    approx_kl            | 6.407656e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.15        |
# |    explained_variance   | 0            |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0568      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.0046       |
# |    value_loss           | 9.1          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.04e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 32           |
# |    time_elapsed         | 3808         |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 6.500058e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.14        |
# |    explained_variance   | -0.309       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0595      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.00492      |
# |    value_loss           | 0.00477      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | -6.02e-05   |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 33          |
# |    time_elapsed         | 3923        |
# |    total_timesteps      | 26400       |
# | train/                  |             |
# |    approx_kl            | 7.16506e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -6.13       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 1e-06       |
# |    loss                 | -0.055      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00475     |
# |    value_loss           | 9.33        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.1e-05     |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 34           |
# |    time_elapsed         | 4024         |
# |    total_timesteps      | 27200        |
# | train/                  |              |
# |    approx_kl            | 7.097259e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.13        |
# |    explained_variance   | -0.355       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0569      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | 0.00509      |
# |    value_loss           | 0.00486      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.12e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 35            |
# |    time_elapsed         | 4122          |
# |    total_timesteps      | 28000         |
# | train/                  |               |
# |    approx_kl            | 6.6153254e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.12         |
# |    explained_variance   | 0             |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0554       |
# |    n_updates            | 340           |
# |    policy_gradient_loss | 0.00543       |
# |    value_loss           | 8.49          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.19e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 36            |
# |    time_elapsed         | 4221          |
# |    total_timesteps      | 28800         |
# | train/                  |               |
# |    approx_kl            | 5.9857295e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.11         |
# |    explained_variance   | -0.185        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0554       |
# |    n_updates            | 350           |
# |    policy_gradient_loss | 0.0062        |
# |    value_loss           | 0.00478       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.34e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 37           |
# |    time_elapsed         | 4324         |
# |    total_timesteps      | 29600        |
# | train/                  |              |
# |    approx_kl            | 8.085028e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.1         |
# |    explained_variance   | -0.193       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0549      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00576      |
# |    value_loss           | 0.00475      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.41e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 38           |
# |    time_elapsed         | 4426         |
# |    total_timesteps      | 30400        |
# | train/                  |              |
# |    approx_kl            | 7.485546e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.1         |
# |    explained_variance   | -0.194       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0566      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00646      |
# |    value_loss           | 0.0048       |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.11e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 39            |
# |    time_elapsed         | 4524          |
# |    total_timesteps      | 31200         |
# | train/                  |               |
# |    approx_kl            | 0.00010604017 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.09         |
# |    explained_variance   | -0.369        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0539       |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 0.00582       |
# |    value_loss           | 0.00476       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.44e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 40           |
# |    time_elapsed         | 4623         |
# |    total_timesteps      | 32000        |
# | train/                  |              |
# |    approx_kl            | 7.301755e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.08        |
# |    explained_variance   | -0.154       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0561      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00652      |
# |    value_loss           | 0.00474      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.07e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 41            |
# |    time_elapsed         | 4726          |
# |    total_timesteps      | 32800         |
# | train/                  |               |
# |    approx_kl            | 8.3690284e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.07         |
# |    explained_variance   | -0.234        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0575       |
# |    n_updates            | 400           |
# |    policy_gradient_loss | 0.0056        |
# |    value_loss           | 0.00486       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -5.96e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 42           |
# |    time_elapsed         | 4827         |
# |    total_timesteps      | 33600        |
# | train/                  |              |
# |    approx_kl            | 7.597997e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.06        |
# |    explained_variance   | -0.281       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0541      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.00617      |
# |    value_loss           | 0.00472      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -5.95e-05    |
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 43           |
# |    time_elapsed         | 4924         |
# |    total_timesteps      | 34400        |
# | train/                  |              |
# |    approx_kl            | 9.877145e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.05        |
# |    explained_variance   | -0.29        |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0553      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00663      |
# |    value_loss           | 0.00461      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.08e-05     |
# | time/                   |               |
# |    fps                  | 6             |
# |    iterations           | 44            |
# |    time_elapsed         | 5029          |
# |    total_timesteps      | 35200         |
# | train/                  |               |
# |    approx_kl            | 0.00010040142 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.04         |
# |    explained_variance   | -0.168        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0567       |
# |    n_updates            | 430           |
# |    policy_gradient_loss | 0.00659       |
# |    value_loss           | 0.00465       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -6.03e-05    |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 45           |
# |    time_elapsed         | 5132         |
# |    total_timesteps      | 36000        |
# | train/                  |              |
# |    approx_kl            | 9.167462e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6.03        |
# |    explained_variance   | -0.268       |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0555      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.00714      |
# |    value_loss           | 0.0047       |
# ------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 1              |
# |    ep_rew_mean          | -5.77e-05      |
# | time/                   |                |
# |    fps                  | 7              |
# |    iterations           | 46             |
# |    time_elapsed         | 5236           |
# |    total_timesteps      | 36800          |
# | train/                  |                |
# |    approx_kl            | 0.000117242715 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -6.02          |
# |    explained_variance   | -0.281         |
# |    learning_rate        | 1e-06          |
# |    loss                 | -0.0548        |
# |    n_updates            | 450            |
# |    policy_gradient_loss | 0.00625        |
# |    value_loss           | 0.0047         |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.08e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 47            |
# |    time_elapsed         | 5340          |
# |    total_timesteps      | 37600         |
# | train/                  |               |
# |    approx_kl            | 0.00013033346 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6.01         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.052        |
# |    n_updates            | 460           |
# |    policy_gradient_loss | 0.00639       |
# |    value_loss           | 5.94          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.15e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 48            |
# |    time_elapsed         | 5447          |
# |    total_timesteps      | 38400         |
# | train/                  |               |
# |    approx_kl            | 0.00014365383 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -6            |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 68.5          |
# |    n_updates            | 470           |
# |    policy_gradient_loss | 0.007         |
# |    value_loss           | 17.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | -5.6e-05     |
# | time/                   |              |
# |    fps                  | 7            |
# |    iterations           | 49           |
# |    time_elapsed         | 5554         |
# |    total_timesteps      | 39200        |
# | train/                  |              |
# |    approx_kl            | 9.421364e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -6           |
# |    explained_variance   | -0.0195      |
# |    learning_rate        | 1e-06        |
# |    loss                 | -0.0534      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00799      |
# |    value_loss           | 0.005        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.89e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 50            |
# |    time_elapsed         | 5658          |
# |    total_timesteps      | 40000         |
# | train/                  |               |
# |    approx_kl            | 0.00014121986 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -0.0468       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0536       |
# |    n_updates            | 490           |
# |    policy_gradient_loss | 0.00734       |
# |    value_loss           | 0.00446       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.88e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 51            |
# |    time_elapsed         | 5767          |
# |    total_timesteps      | 40800         |
# | train/                  |               |
# |    approx_kl            | 0.00011976615 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -0.0533       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0513       |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 0.00806       |
# |    value_loss           | 0.00453       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -0.83         |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 52            |
# |    time_elapsed         | 5875          |
# |    total_timesteps      | 41600         |
# | train/                  |               |
# |    approx_kl            | 8.6830114e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.96         |
# |    explained_variance   | -0.061        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0526       |
# |    n_updates            | 510           |
# |    policy_gradient_loss | 0.00779       |
# |    value_loss           | 0.0046        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.79e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 53            |
# |    time_elapsed         | 5986          |
# |    total_timesteps      | 42400         |
# | train/                  |               |
# |    approx_kl            | 0.00013051502 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.95         |
# |    explained_variance   | 0             |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0507       |
# |    n_updates            | 520           |
# |    policy_gradient_loss | 0.00683       |
# |    value_loss           | 8.61          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6e-05        |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 54            |
# |    time_elapsed         | 6096          |
# |    total_timesteps      | 43200         |
# | train/                  |               |
# |    approx_kl            | 0.00010938891 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.94         |
# |    explained_variance   | -0.107        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.053        |
# |    n_updates            | 530           |
# |    policy_gradient_loss | 0.00842       |
# |    value_loss           | 0.0047        |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.83e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 55            |
# |    time_elapsed         | 6206          |
# |    total_timesteps      | 44000         |
# | train/                  |               |
# |    approx_kl            | 0.00012835837 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.93         |
# |    explained_variance   | -0.171        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0546       |
# |    n_updates            | 540           |
# |    policy_gradient_loss | 0.00844       |
# |    value_loss           | 0.00458       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.82e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 56            |
# |    time_elapsed         | 6316          |
# |    total_timesteps      | 44800         |
# | train/                  |               |
# |    approx_kl            | 0.00013022526 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.91         |
# |    explained_variance   | -0.176        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0508       |
# |    n_updates            | 550           |
# |    policy_gradient_loss | 0.00816       |
# |    value_loss           | 0.00458       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -6.06e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 57            |
# |    time_elapsed         | 6426          |
# |    total_timesteps      | 45600         |
# | train/                  |               |
# |    approx_kl            | 0.00014162489 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.9          |
# |    explained_variance   | -0.158        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.053        |
# |    n_updates            | 560           |
# |    policy_gradient_loss | 0.00788       |
# |    value_loss           | 0.00441       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.83e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 58            |
# |    time_elapsed         | 6534          |
# |    total_timesteps      | 46400         |
# | train/                  |               |
# |    approx_kl            | 0.00013361408 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.89         |
# |    explained_variance   | -0.117        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0522       |
# |    n_updates            | 570           |
# |    policy_gradient_loss | 0.00881       |
# |    value_loss           | 0.00443       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.82e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 59            |
# |    time_elapsed         | 6647          |
# |    total_timesteps      | 47200         |
# | train/                  |               |
# |    approx_kl            | 0.00014106289 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.88         |
# |    explained_variance   | -0.189        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0499       |
# |    n_updates            | 580           |
# |    policy_gradient_loss | 0.00896       |
# |    value_loss           | 0.00476       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.98e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 60            |
# |    time_elapsed         | 6759          |
# |    total_timesteps      | 48000         |
# | train/                  |               |
# |    approx_kl            | 0.00017362506 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.86         |
# |    explained_variance   | -0.0698       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0516       |
# |    n_updates            | 590           |
# |    policy_gradient_loss | 0.0085        |
# |    value_loss           | 0.00454       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.57e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 61            |
# |    time_elapsed         | 6872          |
# |    total_timesteps      | 48800         |
# | train/                  |               |
# |    approx_kl            | 0.00014434903 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.85         |
# |    explained_variance   | -0.186        |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0492       |
# |    n_updates            | 600           |
# |    policy_gradient_loss | 0.00785       |
# |    value_loss           | 0.00429       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.75e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 62            |
# |    time_elapsed         | 6984          |
# |    total_timesteps      | 49600         |
# | train/                  |               |
# |    approx_kl            | 0.00016566477 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.84         |
# |    explained_variance   | -0.15         |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0474       |
# |    n_updates            | 610           |
# |    policy_gradient_loss | 0.00885       |
# |    value_loss           | 0.00442       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1             |
# |    ep_rew_mean          | -5.62e-05     |
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 63            |
# |    time_elapsed         | 7096          |
# |    total_timesteps      | 50400         |
# | train/                  |               |
# |    approx_kl            | 0.00012066521 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.82         |
# |    explained_variance   | -0.0987       |
# |    learning_rate        | 1e-06         |
# |    loss                 | -0.0511       |
# |    n_updates            | 620           |
# |    policy_gradient_loss | 0.00998       |
# |    value_loss           | 0.00443       |
# -------------------------------------------

# %% [markdown]
# (b) Run the following code for RL algorithm: A2C

# %%
num_cpu = 8
env=make_vec_env(openDSSenv34,n_envs=num_cpu,seed=0)

rms_prop_eps = 1e-5

# Training the model for A2C
policy_kwargs = dict(
    features_extractor_class=CustomNN, # chage with CustomCNN to use CNN as feature extractor
    features_extractor_kwargs=dict(features_dim=128),
    optimizer_class = th.optim.RMSprop,
    optimizer_kwargs = dict(alpha=0.89, eps=rms_prop_eps, weight_decay=0)
)
model = A2C('MultiInputPolicy', env,tensorboard_log="logger/", policy_kwargs=policy_kwargs, verbose=1, n_steps=100,
        use_rms_prop=False,
            gamma=1.00,
            learning_rate=0.000001,
            ).learn(total_timesteps=20000, n_eval_episodes=1, log_interval=1, tb_log_name="R1_A2C")

log_dir = "."
model.save(log_dir + "r1_MG_bus_mlp_with_entropy_05_multi_env_normal_A2C"+str(datetime.datetime.now().day)+"_"+str(datetime.datetime.now().hour)+"_"+str(datetime.datetime.now().minute))

# %% [markdown]
# (c) Run the following code for RL algorithm: TRPO

# %%
num_cpu = 8
env=make_vec_env(openDSSenv34,n_envs=num_cpu,seed=0)

rms_prop_eps = 1e-5

# Training the model for TRPO
policy_kwargs = dict(
    features_extractor_class=CustomNN, # chage with CustomCNN to use CNN as feature extractor
    features_extractor_kwargs=dict(features_dim=128),
    optimizer_class = th.optim.RMSprop,
    optimizer_kwargs = dict(alpha=0.89, eps=rms_prop_eps, weight_decay=0)
)

model = TRPO('MultiInputPolicy', env,tensorboard_log="logger/", policy_kwargs=policy_kwargs, verbose=1, n_steps=200, 
            gamma=1.00,
            learning_rate=0.000001,
            batch_size=100).learn(total_timesteps=80000, log_interval=1, tb_log_name="R1_Microgrid-TRPO")

log_dir = "."
model.save(log_dir + "r1_MG_TRPO"+str(datetime.datetime.now().day)+"_"+str(datetime.datetime.now().hour)+"_"+str(datetime.datetime.now().minute))

# %% [markdown]
# The training is done. Now, We can test it for post-disaster condition with following changes.
# 1. Change line 73 in DSS_Initialize.py for testing each scenario, which is 'factor = 0.5'.
# 2. Set the 'factor' to 0.5, 1, 1.5 and rerun following code.
# 3. Collect the result to generate Table II in the report.

# %%
import openDSSenv34
import importlib
importlib.reload(openDSSenv34)
from openDSSenv34 import openDSSenv34

env = openDSSenv34()
obs, DSSCKTOBJ, G_INIT = env.new_test_func()
start = time.time()
obs = {key: th.as_tensor([_obs]) for (key, _obs) in obs.items()}
obs['loss'] = th.as_tensor([[obs['loss']]])
#obs['TopologicalConstr'] = torch.as_tensor([[obs['TopologicalConstr']]])
obs['VoltageViolation'] = th.as_tensor([[obs['VoltageViolation']]])
obs['FlowViolation'] = th.as_tensor([[obs['FlowViolation']]])


action, values, log_probs = model.policy.forward(obs)
#print(obs['loss'])
DCKTOBJ=take_action(DSSCKTOBJ,action)
OBS=get_state(DSSCKTOBJ,G_INIT)
print("The loss is:",OBS['loss'])
print("The topology violation status is:",OBS['TopologicalConstr'])
print("The voltage violation status is: ",OBS['VoltageViolation'])
print("The branch flow violation status is: ",OBS['FlowViolation'])
print("The amount of unserved energy is:",OBS['Unserved Energy']*1000*25)
#print("The voltage violation status is:",OBS['VoltageViolation'])
print("The convergence status is:",OBS['Convergence'])
print("For Unity Load: The Optimal Configuration is :.{}",action)
end = time.time()
print("Run time [s]: ",end-start)
# Out:
# Initializing Microgrid env with sectionalizing and tie switches
# Env initialized
# The loss is: 0.000301110364867225
# The topology violation status is: 400
# The voltage violation status is:  0
# The branch flow violation status is:  0
# The amount of unserved energy is: 1.483311523259279
# The convergence status is: 0
# For Unity Load: The Optimal Configuration is :.{} tensor([[0., 0., 1., 1., 0., 1., 0., 1., 0.]])
# Run time [s]:  0.06399822235107422
